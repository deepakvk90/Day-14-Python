# %% [markdown]
# # Day 14

# %% [markdown]
# # Pandas Library

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\archive (4)\tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ..                                            ...     ...                 ...
# 413                            Spector, Mr. Woolf    male           A.5. 3236
# 414                  Oliva y Ocana, Dona. Fermina  female            PC 17758
# 415                  Saether, Mr. Simon Sivertsen    male  SOTON/O.Q. 3101262
# 416                           Ware, Mr. Frederick    male              359309
# 417                      Peter, Master. Michael J    male                2668
#
#     Cabin Embarked
# ...

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0            892         0       3      0      0
# 1            893         1       3      1      0
# 2            894         0       2      0      0
# 3            895         0       3      0      0
# 4            896         1       3      1      1
# ..           ...       ...     ...    ...    ...
# 413         1305         0       3      0      0
# 414         1306         1       1      0      0
# 415         1307         0       3      0      0
# 416         1308         0       3      0      0
# 417         1309         0       3      1      1
#
# [418 rows x 5 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                  Ticket
# 0                330911
# 1                363272
# 2                240276
# 3                315154
# 4               3101298
# ..                  ...
# 413           A.5. 3236
# 414            PC 17758
# 415  SOTON/O.Q. 3101262
# 416              359309
# 417                2668
#
# [418 rows x 1 columns]

# %%
df[['Ticket']][4:16]
# Out:
#            Ticket
# 4         3101298
# 5            7538
# 6          330972
# 7          248738
# 8            2657
# 9       A/4 48871
# 10         349220
# 11            694
# 12          21228
# 13          24065
# 14    W.E.P. 5734
# 15  SC/PARIS 2167

# %%
df[['Fare']][4:16]
# Out:
#        Fare
# 4   12.2875
# 5    9.2250
# 6    7.6292
# 7   29.0000
# 8    7.2292
# 9   24.1500
# 10   7.8958
# 11  26.0000
# 12  82.2667
# 13  26.0000
# 14  61.1750
# 15  27.7208

# %%
df[['Ticket']][4:16:2]
# Out:
#          Ticket
# 4       3101298
# 6        330972
# 8          2657
# 10       349220
# 12        21228
# 14  W.E.P. 5734

# %%
df[['Ticket','Cabin']]
# Out:
#                  Ticket Cabin
# 0                330911   NaN
# 1                363272   NaN
# 2                240276   NaN
# 3                315154   NaN
# 4               3101298   NaN
# ..                  ...   ...
# 413           A.5. 3236   NaN
# 414            PC 17758  C105
# 415  SOTON/O.Q. 3101262   NaN
# 416              359309   NaN
# 417                2668   NaN
#
# [418 rows x 2 columns]

# %%
df[['Ticket','Cabin']][4:17]
# Out:
#            Ticket Cabin
# 4         3101298   NaN
# 5            7538   NaN
# 6          330972   NaN
# 7          248738   NaN
# 8            2657   NaN
# 9       A/4 48871   NaN
# 10         349220   NaN
# 11            694   NaN
# 12          21228   B45
# 13          24065   NaN
# 14    W.E.P. 5734   E31
# 15  SC/PARIS 2167   NaN
# 16         233734   NaN

# %%
df[['Ticket','Cabin']][4:17:3]
# Out:
#      Ticket Cabin
# 4   3101298   NaN
# 7    248738   NaN
# 10   349220   NaN
# 13    24065   NaN
# 16   233734   NaN

# %%
df[['Ticket','Cabin','Name']][4:17:3]
# Out:
#      Ticket Cabin                                          Name
# 4   3101298   NaN  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 7    248738   NaN                  Caldwell, Mr. Albert Francis
# 10   349220   NaN                              Ilieff, Mr. Ylio
# 13    24065   NaN                          Howard, Mr. Benjamin
# 16   233734   NaN                             Keane, Mr. Daniel

# %%
df['new_col'] = 2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.insert(loc = 3, column = 'Food', value = 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0            892         0       3     0
# 1            893         1       3     0
# 2            894         0       2     0
# 3            895         0       3     0
# 4            896         1       3     0
# ..           ...       ...     ...   ...
# 413         1305         0       3     0
# 414         1306         1       1     0
# 415         1307         0       3     0
# 416         1308         0       3     0
# 417         1309         0       3     0
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# ...

# %%
df.insert(loc = 6, column = 'equipments', value = "oxygen cylinder")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0            892         0       3     0
# 1            893         1       3     0
# 2            894         0       2     0
# 3            895         0       3     0
# 4            896         1       3     0
# ..           ...       ...     ...   ...
# 413         1305         0       3     0
# 414         1306         1       1     0
# 415         1307         0       3     0
# 416         1308         0       3     0
# 417         1309         0       3     0
#
#                                              Name     Sex       equipments  \
# 0                                Kelly, Mr. James    male  oxygen cylinder
# 1                Wilkes, Mrs. James (Ellen Needs)  female  oxygen cylinder
# 2                       Myles, Mr. Thomas Francis    male  oxygen cylinder
# 3                                Wirz, Mr. Albert    male  oxygen cylinder
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  oxygen cylinder
# ...
